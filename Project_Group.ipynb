# %% [markdown]
# <a href="https://colab.research.google.com/github/sitthatkaja/data_viz_2022/blob/main/Project_Group.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #กลุ่ม คิดชื่อไม่ออก

# %% [markdown]
# #โดยไฟล์แต่ละไฟล์ ได้แก่
# - case_01.csv > รายงานจำนวนผู้ติดเชื้อ COVID-19 ประจำวัน (12/01/2020 - 11/08/2021)
#
# - case_02.csv > รายงานจำนวนผู้ติดเชื้อ COVID-19 ประจำวัน (12/8/2021 - 25/10/2021)
#
# - case_03.csv > รายงานจำนวนผู้ติดเชื้อ COVID-19 ประจำวัน (26/10/2021 - 27/02/2022)
#
# - case_04.csv > รายงานจำนวนผู้ติดเชื้อ COVID-19 ประจำวัน (28/2/2022	 - 18/03/2022)
#
# - malignant.csv > ข้อมูลอัตราป่วยด้วยโรคมะเร็งปอดของผู้ป่วยในโรงพยาบาล ปี 2560 - 2563

# %% [markdown]
# #Google styudio

# %% [markdown]
# #https://datastudio.google.com/reporting/01891f14-5e69-40f5-ac27-335611679c62

# %% [markdown]
# #ไฟล์ที่ใช้ทั้งหมด : https://drive.google.com/drive/folders/1QtkQ5V5OTRTThoEm4pGhfIjb408I-m3D

# %% [markdown]
# #ไฟล์นำเสนอ

# %% [markdown]
# #https://www.canva.com/design/DAE8DxBZisM/tiljvAMEX3lQMa2JUyk_6A/edit?utm_content=DAE8DxBZisM&utm_campaign=designshare&utm_medium=link2&utm_source=sharebutton

# %%
import pandas as pd #ทำงานกับข้อมูลลักษณะตาราง

# %%
from google.colab import drive #เชื่อม Google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os # os ไว้จัดการไฟล์และถาท ถาทคือที่อยู่ของไฟล์

# %%
path = '/content/drive/My Drive/Project' #ชื่อ path ชี้ไปไฟล์ที่เราต้องการ
data_01 = pd.read_csv(os.path.join(path,'case_01.csv'))
data_01
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 816984  816985     11/8/2021     10/8/2021  หญิง   8.0   ปี    Thailand
# 816985  816986     11/8/2021     10/8/2021   ชาย  14.0   ปี    Thailand
# 816986  816987     11/8/2021     10/8/2021   ชาย  59.0   ปี    Thailand
# 816987  816988     11/8/2021     10/8/2021  หญิง  34.0   ปี    Thailand
# 816988  816989     11/8/2021     10/8/2021  หญิง  19.0   ปี    Thailand
#
#        province_of_isolation  \
# 0              กรุงเทพมหานคร
# 1              กรุงเทพมหานคร
# 2                     นครปฐม
# 3              กรุงเทพมหานคร
# 4                    นนทบุรี
# ...                      ...
# 816984               สระแก้ว
# 816985               สระแก้ว
# 816986               สระแก้ว
# 816987               สระแก้ว
# 816988               สระแก้ว
#
#                                                      risk province_of_onset  \
# 0                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2                        คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...                                                   ...               ...
# 816984                               อยู่ระหว่างการสอบสวน           สระแก้ว
# 816985                               อยู่ระหว่างการสอบสวน           สระแก้ว
# 816986  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...           สระแก้ว
# 816987                                              อื่นๆ     กรุงเทพมหานคร
# 816988                                              อื่นๆ   พระนครศรีอยุธยา
#
#        district_of_onset
# 0                    NaN
# 1                    NaN
# 2                  เมือง
# 3                    NaN
# 4                    NaN
# ...                  ...
# 816984           ตาพระยา
# 816985           ตาพระยา
# 816986        อรัญประเทศ
# 816987       บางขุนเทียน
# 816988             อุทัย
#
# [816989 rows x 11 columns]

# %%
data_02 = pd.read_csv(os.path.join(path,'case_02.csv'))
data_02
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0         816990     12/8/2021     11/8/2021   ชาย   7.0   ปี    Thailand
# 1         816991     12/8/2021     11/8/2021   ชาย   1.0   ปี    Thailand
# 2         816992     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
# 3         816993     12/8/2021     11/8/2021  หญิง  33.0   ปี    Thailand
# 4         816994     12/8/2021     11/8/2021  หญิง  14.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1042163  1859153    25/10/2021    24/10/2021   ชาย  45.0   ปี         NaN
# 1042164  1859154    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042165  1859155    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042166  1859156    25/10/2021    24/10/2021   ชาย  24.0   ปี         NaN
# 1042167  1859157    25/10/2021    24/10/2021   ชาย  25.0   ปี         NaN
#
#         province_of_isolation                                         risk  \
# 0                    เชียงราย                                        อื่นๆ
# 1                    เชียงราย                                        อื่นๆ
# 2                    เชียงราย                                        อื่นๆ
# 3                    เชียงราย                                        อื่นๆ
# 4                    เชียงราย  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                          ...
# 1042163         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042164         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042165         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042166         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042167             เชียงใหม่                             ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset
# 0                     NaN               NaN
# 1                     NaN               NaN
# 2                     NaN               NaN
# 3                     NaN               NaN
# 4                     NaN               NaN
# ...                   ...               ...
# 1042163               NaN               NaN
# 1042164               NaN               NaN
# 1042165               NaN               NaN
# 1042166               NaN               NaN
# 1042167               NaN               NaN
#
# [1042168 rows x 11 columns]

# %%
data_03 = pd.read_csv(os.path.join(path,'case_03.csv'))
data_03
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010455  2869613     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010456  2869614     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010457  2869615     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010458  2869616     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
#
#         province_of_isolation                                           risk  \
# 0                       ลำปาง                                          อื่นๆ
# 1                       ลำปาง                                          อื่นๆ
# 2                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 3                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 4                       ลำปาง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                            ...
# 1010454         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010455         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010456               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010457               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010458               ปัตตานี                               ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset  Unnamed: 11
# 0                   ลำปาง        เมืองลำปาง          NaN
# 1                   ลำปาง        เมืองลำปาง          NaN
# 2                   ลำปาง          ห้างฉัตร          NaN
# 3                   ลำปาง          ห้างฉัตร          NaN
# 4                   ลำปาง        เมืองลำปาง          NaN
# ...                   ...               ...          ...
# 1010454               NaN               NaN          NaN
# 1010455               NaN               NaN          NaN
# 1010456               NaN               NaN          NaN
# 1010457               NaN               NaN          NaN
# 1010458               NaN               NaN          NaN
#
# [1010459 rows x 12 columns]

# %%
data_04 = pd.read_csv(os.path.join(path,'case_04.csv'))
data_04
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี    Thailand
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี    Thailand
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# 0                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                      ...                                          ...
# 433548         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433549         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433550         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433551                 สงขลา                             ทัณฑสถาน/เรือนจำ
# 433552                 สงขลา                             ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0                  พะเยา        เมืองพะเยา
# 1                  พะเยา        เมืองพะเยา
# 2                  พะเยา        เมืองพะเยา
# 3                  พะเยา        เมืองพะเยา
# 4                  พะเยา        เมืองพะเยา
# ...                  ...               ...
# 433548               NaN               NaN
# 433549               NaN               NaN
# 433550               NaN               NaN
# 433551               NaN               NaN
# 433552               NaN               NaN
#
# [433553 rows x 11 columns]

# %% [markdown]
# #ดูว่าข้อมูลมี data missing

# %%
data_01.isnull() #ดูว่าข้อมูลนั้นมี Missing รึป่าว
# Out:
#           No.  announce_date  Notified date    sex    age   Unit  nationality  \
# 0       False          False           True  False  False  False        False
# 1       False          False           True  False  False  False        False
# 2       False          False           True  False  False  False        False
# 3       False          False           True  False  False  False        False
# 4       False          False           True  False  False  False        False
# ...       ...            ...            ...    ...    ...    ...          ...
# 816984  False          False          False  False  False  False        False
# 816985  False          False          False  False  False  False        False
# 816986  False          False          False  False  False  False        False
# 816987  False          False          False  False  False  False        False
# 816988  False          False          False  False  False  False        False
#
#         province_of_isolation   risk  province_of_onset  district_of_onset
# 0                       False  False              False               True
# 1                       False  False              False               True
# 2                       False  False              False              False
# 3                       False  False              False               True
# 4                       False  False              False               True
# ...                       ...    ...                ...                ...
# 816984                  False  False              False              False
# 816985                  False  False              False              False
# 816986                  False  False              False              False
# 816987                  False  False              False              False
# 816988                  False  False              False              False
#
# [816989 rows x 11 columns]

# %%
data_02.isnull() #ดูว่าข้อมูลนั้นมี Missing รึป่าว
# Out:
#            No.  announce_date  Notified date    sex    age   Unit  \
# 0        False          False          False  False  False  False
# 1        False          False          False  False  False  False
# 2        False          False          False  False  False  False
# 3        False          False          False  False  False  False
# 4        False          False          False  False  False  False
# ...        ...            ...            ...    ...    ...    ...
# 1042163  False          False          False  False  False  False
# 1042164  False          False          False  False  False  False
# 1042165  False          False          False  False  False  False
# 1042166  False          False          False  False  False  False
# 1042167  False          False          False  False  False  False
#
#          nationality  province_of_isolation   risk  province_of_onset  \
# 0              False                  False  False               True
# 1              False                  False  False               True
# 2              False                  False  False               True
# 3              False                  False  False               True
# 4              False                  False  False               True
# ...              ...                    ...    ...                ...
# 1042163         True                  False  False               True
# 1042164         True                  False  False               True
# 1042165         True                  False  False               True
# 1042166         True                  False  False               True
# 1042167         True                  False  False               True
#
#          district_of_onset
# 0                     True
# 1                     True
# 2                     True
# 3                     True
# 4                     True
# ...                    ...
# 1042163               True
# 1042164               True
# 1042165               True
# 1042166               True
# 1042167               True
#
# [1042168 rows x 11 columns]

# %%
data_03.isnull() #ดูว่าข้อมูลนั้นมี Missing รึป่าว
# Out:
#            No.  announce_date  Notified date    sex    age   Unit  \
# 0        False          False          False  False  False  False
# 1        False          False          False  False  False  False
# 2        False          False          False  False  False  False
# 3        False          False          False  False  False  False
# 4        False          False          False  False  False  False
# ...        ...            ...            ...    ...    ...    ...
# 1010454  False          False          False  False   True   True
# 1010455  False          False          False  False   True   True
# 1010456  False          False          False  False   True   True
# 1010457  False          False          False  False   True   True
# 1010458  False          False          False  False   True   True
#
#          nationality  province_of_isolation   risk  province_of_onset  \
# 0              False                  False  False              False
# 1              False                  False  False              False
# 2              False                  False  False              False
# 3              False                  False  False              False
# 4              False                  False  False              False
# ...              ...                    ...    ...                ...
# 1010454         True                  False  False               True
# 1010455         True                  False  False               True
# 1010456         True                  False  False               True
# 1010457         True                  False  False               True
# 1010458         True                  False  False               True
#
#          district_of_onset  Unnamed: 11
# 0                    False         True
# 1                    False         True
# 2                    False         True
# 3                    False         True
# 4                    False         True
# ...                    ...          ...
# 1010454               True         True
# 1010455               True         True
# 1010456               True         True
# 1010457               True         True
# 1010458               True         True
#
# [1010459 rows x 12 columns]

# %%
data_04.isnull() #ดูว่าข้อมูลนั้นมี Missing รึป่าว
# Out:
#           No.  announce_date  Notified date    sex    age   Unit  nationality  \
# 0       False          False          False  False  False  False        False
# 1       False          False          False  False  False  False        False
# 2       False          False          False  False  False  False        False
# 3       False          False          False  False  False  False        False
# 4       False          False          False  False  False  False        False
# ...       ...            ...            ...    ...    ...    ...          ...
# 433548  False          False          False  False   True   True         True
# 433549  False          False          False  False   True   True         True
# 433550  False          False          False  False   True   True         True
# 433551  False          False          False  False   True   True         True
# 433552  False          False          False  False   True   True         True
#
#         province_of_isolation   risk  province_of_onset  district_of_onset
# 0                       False  False              False              False
# 1                       False  False              False              False
# 2                       False  False              False              False
# 3                       False  False              False              False
# 4                       False  False              False              False
# ...                       ...    ...                ...                ...
# 433548                  False  False               True               True
# 433549                  False  False               True               True
# 433550                  False  False               True               True
# 433551                  False  False               True               True
# 433552                  False  False               True               True
#
# [433553 rows x 11 columns]

# %% [markdown]
# #สรุปข้อมูลเป็นรายคอลลัมม์ว่ามี missing

# %%
data_01.isnull().any() #any สรุปข้อมูลเป็นรายคอลลัมม์ว่ามี missing ไหม
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
data_02.isnull().any() #any สรุปข้อมูลเป็นรายคอลลัมม์ว่ามี missing ไหม
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation    False
# risk                     False
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
data_03.isnull().any() #any สรุปข้อมูลเป็นรายคอลลัมม์ว่ามี missing ไหม
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# Unnamed: 11               True
# dtype: bool

# %%
data_04.isnull().any() #any สรุปข้อมูลเป็นรายคอลลัมม์ว่ามี missing ไหม
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation    False
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# #รวมตาราง

# %%
data_merged = pd.concat([data_01,data_02,data_03,data_04])
data_merged
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0             1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1             2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2             3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4             5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 433548         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433549         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433550         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433551                 สงขลา                  ทัณฑสถาน/เรือนจำ
# 433552                 สงขลา                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset  Unnamed: 11
# 0          กรุงเทพมหานคร               NaN          NaN
# 1          กรุงเทพมหานคร               NaN          NaN
# 2                 นครปฐม             เมือง          NaN
# 3          กรุงเทพมหานคร               NaN          NaN
# 4          กรุงเทพมหานคร               NaN          NaN
# ...                  ...               ...          ...
# 433548               NaN               NaN          NaN
# 433549               NaN               NaN          NaN
# 433550               NaN               NaN          NaN
# 433551               NaN               NaN          NaN
# 433552               NaN               NaN          NaN
#
# [3303169 rows x 12 columns]

# %%
data_new = data_merged[['No.','announce_date','sex','age','Unit','province_of_onset','risk']]
data_new
# Out:
#             No. announce_date   sex   age Unit province_of_onset  \
# 0             1     12/1/2020  หญิง  61.0   ปี     กรุงเทพมหานคร
# 1             2     17/1/2020  หญิง  74.0   ปี     กรุงเทพมหานคร
# 2             3     22/1/2020  หญิง  73.0   ปี            นครปฐม
# 3             4     22/1/2020   ชาย  68.0   ปี     กรุงเทพมหานคร
# 4             5     24/1/2020  หญิง  66.0   ปี     กรุงเทพมหานคร
# ...         ...           ...   ...   ...  ...               ...
# 433548  3303165     18/3/2022  หญิง   NaN  NaN               NaN
# 433549  3303166     18/3/2022  หญิง   NaN  NaN               NaN
# 433550  3303167     18/3/2022  หญิง   NaN  NaN               NaN
# 433551  3303168     18/3/2022  หญิง   NaN  NaN               NaN
# 433552  3303169     18/3/2022  หญิง   NaN  NaN               NaN
#
#                                     risk
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ
# 2       คนต่างชาติเดินทางมาจากต่างประเทศ
# 3       คนต่างชาติเดินทางมาจากต่างประเทศ
# 4       คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                                  ...
# 433548                  ทัณฑสถาน/เรือนจำ
# 433549                  ทัณฑสถาน/เรือนจำ
# 433550                  ทัณฑสถาน/เรือนจำ
# 433551                  ทัณฑสถาน/เรือนจำ
# 433552                  ทัณฑสถาน/เรือนจำ
#
# [3303169 rows x 7 columns]

# %%
data_new.isnull().any()
# Out:
# No.                  False
# announce_date        False
# sex                   True
# age                   True
# Unit                  True
# province_of_onset     True
# risk                  True
# dtype: bool

# %%
data_new[['sex']] = data_new[['sex']].fillna('ไม่ได้ระบุ')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
data_new[['Unit']] = data_new[['Unit']].fillna('ปี')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
data_new[['province_of_onset']] = data_new[['province_of_onset']].fillna('ไม่ได้ระบุ')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
data_new[['risk']] = data_new[['risk']].fillna('ไม่ได้ระบุ')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
data_new.isnull().any()
# Out:
# No.                  False
# announce_date        False
# sex                  False
# age                   True
# Unit                 False
# province_of_onset    False
# risk                 False
# dtype: bool

# %%
data_new.dropna()
# Out:
#             No. announce_date         sex   age Unit province_of_onset  \
# 0             1     12/1/2020        หญิง  61.0   ปี     กรุงเทพมหานคร
# 1             2     17/1/2020        หญิง  74.0   ปี     กรุงเทพมหานคร
# 2             3     22/1/2020        หญิง  73.0   ปี            นครปฐม
# 3             4     22/1/2020         ชาย  68.0   ปี     กรุงเทพมหานคร
# 4             5     24/1/2020        หญิง  66.0   ปี     กรุงเทพมหานคร
# ...         ...           ...         ...   ...  ...               ...
# 433445  3303062     18/3/2022  ไม่ได้ระบุ  43.0   ปี        ไม่ได้ระบุ
# 433446  3303063     18/3/2022  ไม่ได้ระบุ  21.0   ปี     กรุงเทพมหานคร
# 433447  3303064     18/3/2022  ไม่ได้ระบุ  22.0   ปี     กรุงเทพมหานคร
# 433448  3303065     18/3/2022  ไม่ได้ระบุ  25.0   ปี     กรุงเทพมหานคร
# 433449  3303066     18/3/2022  ไม่ได้ระบุ  64.0   ปี         กำแพงเพชร
#
#                                     risk
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ
# 2       คนต่างชาติเดินทางมาจากต่างประเทศ
# 3       คนต่างชาติเดินทางมาจากต่างประเทศ
# 4       คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                                  ...
# 433445                             อื่นๆ
# 433446                             อื่นๆ
# 433447                             อื่นๆ
# 433448                             อื่นๆ
# 433449                             อื่นๆ
#
# [3036373 rows x 7 columns]

# %%
data_f = data_new.dropna()

# %%
data_f
# Out:
#             No. announce_date         sex   age Unit province_of_onset  \
# 0             1     12/1/2020        หญิง  61.0   ปี     กรุงเทพมหานคร
# 1             2     17/1/2020        หญิง  74.0   ปี     กรุงเทพมหานคร
# 2             3     22/1/2020        หญิง  73.0   ปี            นครปฐม
# 3             4     22/1/2020         ชาย  68.0   ปี     กรุงเทพมหานคร
# 4             5     24/1/2020        หญิง  66.0   ปี     กรุงเทพมหานคร
# ...         ...           ...         ...   ...  ...               ...
# 433445  3303062     18/3/2022  ไม่ได้ระบุ  43.0   ปี        ไม่ได้ระบุ
# 433446  3303063     18/3/2022  ไม่ได้ระบุ  21.0   ปี     กรุงเทพมหานคร
# 433447  3303064     18/3/2022  ไม่ได้ระบุ  22.0   ปี     กรุงเทพมหานคร
# 433448  3303065     18/3/2022  ไม่ได้ระบุ  25.0   ปี     กรุงเทพมหานคร
# 433449  3303066     18/3/2022  ไม่ได้ระบุ  64.0   ปี         กำแพงเพชร
#
#                                     risk
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ
# 2       คนต่างชาติเดินทางมาจากต่างประเทศ
# 3       คนต่างชาติเดินทางมาจากต่างประเทศ
# 4       คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                                  ...
# 433445                             อื่นๆ
# 433446                             อื่นๆ
# 433447                             อื่นๆ
# 433448                             อื่นๆ
# 433449                             อื่นๆ
#
# [3036373 rows x 7 columns]

# %%
data_f.isnull().any()
# Out:
# No.                  False
# announce_date        False
# sex                  False
# age                  False
# Unit                 False
# province_of_onset    False
# risk                 False
# dtype: bool

# %% [markdown]
# #Percent of missing data from dropna
# เป็นการตรวจสอบว่าเมื่อลบข้อมูลทิ้งไปแล้วเราสูญเสียข้อมูลไปกี่เปอร์เซ็นต์

# %%
before = 3303169
after = 3036373
print(f'before = {before} \nafter = {after}\nwhich is {100*((before-after)/before)}')
# Out:
# before = 3303169
# after = 3036373
# which is 8.076970933064581

# %% [markdown]
# #สร้างตารางภูมิภาค

# %%
data_regions_onset = {'province_of_onset': ['อำนาจเจริญ', 'บึงกาฬ', 'บุรีรัมย์', 'ชัยภูมิ', 'กาฬสินธุ์', 'ขอนแก่น', 'เลย', 'มหาสารคาม', 'มุกดาหาร', 'นครพนม', 'นครราชสีมา', 'หนองบัวลำภู', 'หนองคาย', 'ร้อยเอ็ด', 'สกลนคร', 'ศรีสะเกษ', 'สุรินทร์', 'อุบลราชธานี', 'อุดรธานี', 'ยโสธร','เชียงใหม่', 'เชียงราย', 'ลำปาง', 'ลำพูน', 'แม่ฮ่องสอน', 'น่าน', 'พะเยา', 'แพร่', 'อุตรดิตถ์','ตาก','สุโขทัย', 'พิษณุโลก', 'พิจิตร', 'กำแพงเพชร', 'เพชรบูรณ์','นครสวรรค์', 'อุทัยธานี','อ่างทอง', 'ชัยนาท', 'พระนครศรีอยุธยา', 'กรุงเทพมหานคร', 'ลพบุรี', 'นครปฐม', 'นนทบุรี', 'ปทุมธานี', 'สมุทรปราการ','สมุทรสาคร', 'สมุทรสงคราม','สระบุรี', 'สิงห์บุรี', 'สุพรรณบุรี','นครนายก','ฉะเชิงเทรา', 'จันทบุรี', 'ชลบุรี', 'ปราจีนบุรี', 'ระยอง', 'สระแก้ว', 'ตราด','กาญจนบุรี', 'ราชบุรี','เพชรบุรี', 'ประจวบคีรีขันธ์','ชุมพร', 'นครศรีธรรมราช', 'นราธิวาส', 'ปัตตานี', 'พัทลุง', 'สงขลา', 'สุราษฎร์ธานี', 'ยะลา','กระบี่', 'พังงา', 'ภูเก็ต', 'ระนอง', 'สตูล', 'ตรัง'],
            '6 ภูมิภาค (ภูมิศาสตร์)': ['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','ตะวันตก','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันตก','ตะวันตก','ตะวันตก','ตะวันตก','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้'],
            '4 ภูมิภาค (การเมือง)': ['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้'],
            '6 ภูมิภาค (อุตุนิยมวิทยา)': ['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','กลาง','กลาง','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน'],
            '5 ภูมิภาค (การท่องเที่ยว)': ['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','กลาง','กลาง','กลาง','กลาง','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้']
}

# %%
data_re_on = pd.DataFrame.from_dict(data_regions_onset)
data_re_on
# Out:
#    province_of_onset 6 ภูมิภาค (ภูมิศาสตร์) 4 ภูมิภาค (การเมือง)  \
# 0         อำนาจเจริญ     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 1             บึงกาฬ     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 2          บุรีรัมย์     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 3            ชัยภูมิ     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 4          กาฬสินธุ์     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# ..               ...                    ...                  ...
# 72             พังงา                    ใต้                  ใต้
# 73            ภูเก็ต                    ใต้                  ใต้
# 74             ระนอง                    ใต้                  ใต้
# 75              สตูล                    ใต้                  ใต้
# 76              ตรัง                    ใต้                  ใต้
#
#          6 ภูมิภาค (อุตุนิยมวิทยา) 5 ภูมิภาค (การท่องเที่ยว)
# 0               ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 1               ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 2               ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 3               ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 4               ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# ..                             ...                       ...
# 72  ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน                       ใต้
# 73  ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน                       ใต้
# 74  ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน                       ใต้
# 75  ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน                       ใต้
# 76  ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน                       ใต้
#
# [77 rows x 5 columns]

# %%
covid_data_on = data_f.merge(data_re_on)
covid_data_on
# Out:
#              No. announce_date   sex   age Unit province_of_onset  \
# 0              1     12/1/2020  หญิง  61.0   ปี     กรุงเทพมหานคร
# 1              2     17/1/2020  หญิง  74.0   ปี     กรุงเทพมหานคร
# 2              4     22/1/2020   ชาย  68.0   ปี     กรุงเทพมหานคร
# 3              5     24/1/2020  หญิง  66.0   ปี     กรุงเทพมหานคร
# 4              6     25/1/2020  หญิง  33.0   ปี     กรุงเทพมหานคร
# ...          ...           ...   ...   ...  ...               ...
# 2755699  3292162     18/3/2022   ชาย  53.0   ปี            บึงกาฬ
# 2755700  3292163     18/3/2022  หญิง  34.0   ปี            บึงกาฬ
# 2755701  3292164     18/3/2022  หญิง  54.0   ปี            บึงกาฬ
# 2755702  3292165     18/3/2022  หญิง  54.0   ปี            บึงกาฬ
# 2755703  3292166     18/3/2022  หญิง  16.0   ปี            บึงกาฬ
#
#                                      risk 6 ภูมิภาค (ภูมิศาสตร์)  \
# 0        คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 1        คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 2        คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 3        คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 4        คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# ...                                   ...                    ...
# 2755699                             อื่นๆ     ตะวันออกเฉียงเหนือ
# 2755700                             อื่นๆ     ตะวันออกเฉียงเหนือ
# 2755701                             อื่นๆ     ตะวันออกเฉียงเหนือ
# 2755702                             อื่นๆ     ตะวันออกเฉียงเหนือ
# 2755703                             อื่นๆ     ตะวันออกเฉียงเหนือ
#
#         4 ภูมิภาค (การเมือง) 6 ภูมิภาค (อุตุนิยมวิทยา)  \
# 0                       กลาง                      กลาง
# 1                       กลาง                      กลาง
# 2                       กลาง                      กลาง
# 3                       กลาง                      กลาง
# 4                       กลาง                      กลาง
# ...                      ...                       ...
# 2755699   ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 2755700   ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 2755701   ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 2755702   ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 2755703   ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
#
#         5 ภูมิภาค (การท่องเที่ยว)
# 0                            กลาง
# 1                            กลาง
# 2                            กลาง
# 3                            กลาง
# 4                            กลาง
# ...                           ...
# 2755699        ตะวันออกเฉียงเหนือ
# 2755700        ตะวันออกเฉียงเหนือ
# 2755701        ตะวันออกเฉียงเหนือ
# 2755702        ตะวันออกเฉียงเหนือ
# 2755703        ตะวันออกเฉียงเหนือ
#
# [2755704 rows x 11 columns]

# %%
covid_data_on.isnull().any()
# Out:
# No.                          False
# announce_date                False
# sex                          False
# age                          False
# Unit                         False
# province_of_onset            False
# risk                         False
# 6 ภูมิภาค (ภูมิศาสตร์)       False
# 4 ภูมิภาค (การเมือง)         False
# 6 ภูมิภาค (อุตุนิยมวิทยา)    False
# 5 ภูมิภาค (การท่องเที่ยว)    False
# dtype: bool

# %% [markdown]
# #สร้างตาราง 3

# %%
data_a = pd.read_csv(os.path.join(path,'malignant.csv'))
data_a
# Out:
#                                       county_of_local province_of_onset  \
# 0                                     เขต 1 เชียงใหม่         เชียงใหม่
# 1                                     เขต 1 เชียงใหม่             ลำพูน
# 2                                     เขต 1 เชียงใหม่             ลำปาง
# 3                                     เขต 1 เชียงใหม่              แพร่
# 4                                     เขต 1 เชียงใหม่              น่าน
# ..                                                ...               ...
# 73                                       เขต 12 สงขลา           ปัตตานี
# 74                                       เขต 12 สงขลา              ยะลา
# 75                                       เขต 12 สงขลา          นราธิวาส
# 76                               เขต 13 กรุงเทพมหานคร     กรุงเทพมหานคร
# 77  เขต 14 กรมแพทย์ทหารเรือ, กรมแพทย์ทหารอากาศ, ทั...  กรมแพทย์ทหารเรือ
#
#     ผลลัพธ์ปี 2560 (จังหวัด)  จำนวนครั้งปี 2560 (จังหวัด)  \
# 0                      41.74                          394
# 1                      44.83                           86
# 2                      44.67                          188
# 3                      58.90                          112
# 4                      55.70                          128
# ..                       ...                          ...
# 73                     50.00                           21
# 74                     51.22                           24
# 75                     50.63                           51
# 76                     38.92                          635
# 77                      0.00                            0
#
#     ผลลัพธ์ปี 2561 (จังหวัด)  จำนวนครั้งปี 2561 (จังหวัด)  \
# 0                      40.31                          367
# 1                      52.03                          108
# 2                      47.65                          195
# 3                      56.80                           95
# 4                      56.52                          133
# ..                       ...                          ...
# 73                     62.50                           35
# 74                     43.75                           26
# 75                     44.12                           34
# 76                     39.88                          590
# 77                      0.00                            0
#
#     ผลลัพธ์ปี 2562 (จังหวัด)  จำนวนครั้งปี 2562 (จังหวัด)  \
# 0                      36.56                          311
# 1                      52.98                          125
# 2                      43.20                          196
# 3                      58.73                          113
# 4                      55.70                          127
# ..                       ...                          ...
# 73                     54.35                           29
# 74                     54.72                           31
# 75                     52.24                           43
# 76                     41.49                          640
# 77                      0.00                            0
#
#     ผลลัพธ์ปี 2563 (จังหวัด)  จำนวนครั้งปี 2563 (จังหวัด)
# 0                      38.73                          369
# 1                      61.15                          105
# 2                      44.17                          180
# 3                      49.57                           72
# 4                      44.75                          108
# ..                       ...                          ...
# 73                     52.27                           23
# 74                     39.66                           25
# 75                     49.06                           34
# 76                     41.02                          648
# 77                      0.00                            0
#
# [78 rows x 10 columns]

# %%
data_a.isnull().any()
# Out:
# county_of_local                False
# province_of_onset              False
# ผลลัพธ์ปี 2560 (จังหวัด)       False
# จำนวนครั้งปี 2560 (จังหวัด)    False
# ผลลัพธ์ปี 2561 (จังหวัด)       False
# จำนวนครั้งปี 2561 (จังหวัด)    False
# ผลลัพธ์ปี 2562 (จังหวัด)       False
# จำนวนครั้งปี 2562 (จังหวัด)    False
# ผลลัพธ์ปี 2563 (จังหวัด)       False
# จำนวนครั้งปี 2563 (จังหวัด)    False
# dtype: bool

# %% [markdown]
# #ทำการสร้างตารางใหม่โดยเลือกเฉพาะข้อมูลที่ต้องการ

# %%
data_2563 = data_a[['county_of_local','province_of_onset','ผลลัพธ์ปี 2562 (จังหวัด)','จำนวนครั้งปี 2562 (จังหวัด)','ผลลัพธ์ปี 2563 (จังหวัด)','จำนวนครั้งปี 2563 (จังหวัด)']]

# %%
data_2563
# Out:
#                                       county_of_local province_of_onset  \
# 0                                     เขต 1 เชียงใหม่         เชียงใหม่
# 1                                     เขต 1 เชียงใหม่             ลำพูน
# 2                                     เขต 1 เชียงใหม่             ลำปาง
# 3                                     เขต 1 เชียงใหม่              แพร่
# 4                                     เขต 1 เชียงใหม่              น่าน
# ..                                                ...               ...
# 73                                       เขต 12 สงขลา           ปัตตานี
# 74                                       เขต 12 สงขลา              ยะลา
# 75                                       เขต 12 สงขลา          นราธิวาส
# 76                               เขต 13 กรุงเทพมหานคร     กรุงเทพมหานคร
# 77  เขต 14 กรมแพทย์ทหารเรือ, กรมแพทย์ทหารอากาศ, ทั...  กรมแพทย์ทหารเรือ
#
#     ผลลัพธ์ปี 2562 (จังหวัด)  จำนวนครั้งปี 2562 (จังหวัด)  \
# 0                      36.56                          311
# 1                      52.98                          125
# 2                      43.20                          196
# 3                      58.73                          113
# 4                      55.70                          127
# ..                       ...                          ...
# 73                     54.35                           29
# 74                     54.72                           31
# 75                     52.24                           43
# 76                     41.49                          640
# 77                      0.00                            0
#
#     ผลลัพธ์ปี 2563 (จังหวัด)  จำนวนครั้งปี 2563 (จังหวัด)
# 0                      38.73                          369
# 1                      61.15                          105
# 2                      44.17                          180
# 3                      49.57                           72
# 4                      44.75                          108
# ..                       ...                          ...
# 73                     52.27                           23
# 74                     39.66                           25
# 75                     49.06                           34
# 76                     41.02                          648
# 77                      0.00                            0
#
# [78 rows x 6 columns]

# %%
data_a.isnull().any()
# Out:
# county_of_local                False
# province_of_onset              False
# ผลลัพธ์ปี 2560 (จังหวัด)       False
# จำนวนครั้งปี 2560 (จังหวัด)    False
# ผลลัพธ์ปี 2561 (จังหวัด)       False
# จำนวนครั้งปี 2561 (จังหวัด)    False
# ผลลัพธ์ปี 2562 (จังหวัด)       False
# จำนวนครั้งปี 2562 (จังหวัด)    False
# ผลลัพธ์ปี 2563 (จังหวัด)       False
# จำนวนครั้งปี 2563 (จังหวัด)    False
# dtype: bool

# %% [markdown]
# #รวมข้อมูลทั้ง 3

# %%
table_total = pd.merge(covid_data_on,data_2563,on='province_of_onset')
table_total
# Out:
#              No. announce_date   sex   age Unit province_of_onset  \
# 0              1     12/1/2020  หญิง  61.0   ปี     กรุงเทพมหานคร
# 1              2     17/1/2020  หญิง  74.0   ปี     กรุงเทพมหานคร
# 2              4     22/1/2020   ชาย  68.0   ปี     กรุงเทพมหานคร
# 3              5     24/1/2020  หญิง  66.0   ปี     กรุงเทพมหานคร
# 4              6     25/1/2020  หญิง  33.0   ปี     กรุงเทพมหานคร
# ...          ...           ...   ...   ...  ...               ...
# 2755699  3292162     18/3/2022   ชาย  53.0   ปี            บึงกาฬ
# 2755700  3292163     18/3/2022  หญิง  34.0   ปี            บึงกาฬ
# 2755701  3292164     18/3/2022  หญิง  54.0   ปี            บึงกาฬ
# 2755702  3292165     18/3/2022  หญิง  54.0   ปี            บึงกาฬ
# 2755703  3292166     18/3/2022  หญิง  16.0   ปี            บึงกาฬ
#
#                                      risk 6 ภูมิภาค (ภูมิศาสตร์)  \
# 0        คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 1        คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 2        คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 3        คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 4        คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# ...                                   ...                    ...
# 2755699                             อื่นๆ     ตะวันออกเฉียงเหนือ
# 2755700                             อื่นๆ     ตะวันออกเฉียงเหนือ
# 2755701                             อื่นๆ     ตะวันออกเฉียงเหนือ
# 2755702                             อื่นๆ     ตะวันออกเฉียงเหนือ
# 2755703                             อื่นๆ     ตะวันออกเฉียงเหนือ
#
#         4 ภูมิภาค (การเมือง) 6 ภูมิภาค (อุตุนิยมวิทยา)  \
# 0                       กลาง                      กลาง
# 1                       กลาง                      กลาง
# 2                       กลาง                      กลาง
# 3                       กลาง                      กลาง
# 4                       กลาง                      กลาง
# ...                      ...                       ...
# 2755699   ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 2755700   ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 2755701   ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 2755702   ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 2755703   ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
#
#         5 ภูมิภาค (การท่องเที่ยว)       county_of_local  \
# 0                            กลาง  เขต 13 กรุงเทพมหานคร
# 1                            กลาง  เขต 13 กรุงเทพมหานคร
# 2                            กลาง  เขต 13 กรุงเทพมหานคร
# 3                            กลาง  เขต 13 กรุงเทพมหานคร
# 4                            กลาง  เขต 13 กรุงเทพมหานคร
# ...                           ...                   ...
# 2755699        ตะวันออกเฉียงเหนือ        เขต 8 อุดรธานี
# 2755700        ตะวันออกเฉียงเหนือ        เขต 8 อุดรธานี
# 2755701        ตะวันออกเฉียงเหนือ        เขต 8 อุดรธานี
# 2755702        ตะวันออกเฉียงเหนือ        เขต 8 อุดรธานี
# 2755703        ตะวันออกเฉียงเหนือ        เขต 8 อุดรธานี
#
#          ผลลัพธ์ปี 2562 (จังหวัด)  จำนวนครั้งปี 2562 (จังหวัด)  \
# 0                           41.49                          640
# 1                           41.49                          640
# 2                           41.49                          640
# 3                           41.49                          640
# 4                           41.49                          640
# ...                           ...                          ...
# 2755699                     55.26                           22
# 2755700                     55.26                           22
# 2755701                     55.26                           22
# 2755702                     55.26                           22
# 2755703                     55.26                           22
#
#          ผลลัพธ์ปี 2563 (จังหวัด)  จำนวนครั้งปี 2563 (จังหวัด)
# 0                           41.02                          648
# 1                           41.02                          648
# 2                           41.02                          648
# 3                           41.02                          648
# 4                           41.02                          648
# ...                           ...                          ...
# 2755699                     59.00                           30
# 2755700                     59.00                           30
# 2755701                     59.00                           30
# 2755702                     59.00                           30
# 2755703                     59.00                           30
#
# [2755704 rows x 16 columns]

# %%
table_total.isnull().any()
# Out:
# No.                            False
# announce_date                  False
# sex                            False
# age                            False
# Unit                           False
# province_of_onset              False
# risk                           False
# 6 ภูมิภาค (ภูมิศาสตร์)         False
# 4 ภูมิภาค (การเมือง)           False
# 6 ภูมิภาค (อุตุนิยมวิทยา)      False
# 5 ภูมิภาค (การท่องเที่ยว)      False
# county_of_local                False
# ผลลัพธ์ปี 2562 (จังหวัด)       False
# จำนวนครั้งปี 2562 (จังหวัด)    False
# ผลลัพธ์ปี 2563 (จังหวัด)       False
# จำนวนครั้งปี 2563 (จังหวัด)    False
# dtype: bool

# %% [markdown]
# #ทำการสร้าง data ที่จะทำ dashboard

# %% [markdown]
# #โดยจะทำการศึกษาในปี 2020

# %%
finish = table_total[table_total.announce_date.str.contains('2020')] #การเลือกเฉพาค่าข้อมูลในปี 2020
finish
# Out:
#           No. announce_date   sex   age Unit province_of_onset  \
# 0           1     12/1/2020  หญิง  61.0   ปี     กรุงเทพมหานคร
# 1           2     17/1/2020  หญิง  74.0   ปี     กรุงเทพมหานคร
# 2           4     22/1/2020   ชาย  68.0   ปี     กรุงเทพมหานคร
# 3           5     24/1/2020  หญิง  66.0   ปี     กรุงเทพมหานคร
# 4           6     25/1/2020  หญิง  33.0   ปี     กรุงเทพมหานคร
# ...       ...           ...   ...   ...  ...               ...
# 2696640  5922    26/12/2020  หญิง  47.0   ปี            ชัยนาท
# 2701230  5809    24/12/2020  หญิง  44.0   ปี           อ่างทอง
# 2701231  6689    30/12/2020   ชาย  35.0   ปี           อ่างทอง
# 2717714  6288    29/12/2020   ชาย  55.0   ปี              ตราด
# 2730091  6467    30/12/2020   ชาย  57.0   ปี             ระนอง
#
#                                                 risk 6 ภูมิภาค (ภูมิศาสตร์)  \
# 0                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 1                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 2                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 3                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 4                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# ...                                              ...                    ...
# 2696640                            Cluster สมุทรสาคร                   กลาง
# 2701230                            Cluster สมุทรสาคร                   กลาง
# 2701231  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                   กลาง
# 2717714                            Cluster สมุทรสาคร               ตะวันออก
# 2730091                            Cluster สมุทรสาคร                    ใต้
#
#         4 ภูมิภาค (การเมือง)       6 ภูมิภาค (อุตุนิยมวิทยา)  \
# 0                       กลาง                            กลาง
# 1                       กลาง                            กลาง
# 2                       กลาง                            กลาง
# 3                       กลาง                            กลาง
# 4                       กลาง                            กลาง
# ...                      ...                             ...
# 2696640                 กลาง                            กลาง
# 2701230                 กลาง                            กลาง
# 2701231                 กลาง                            กลาง
# 2717714                 กลาง                        ตะวันออก
# 2730091                  ใต้  ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน
#
#         5 ภูมิภาค (การท่องเที่ยว)       county_of_local  \
# 0                            กลาง  เขต 13 กรุงเทพมหานคร
# 1                            กลาง  เขต 13 กรุงเทพมหานคร
# 2                            กลาง  เขต 13 กรุงเทพมหานคร
# 3                            กลาง  เขต 13 กรุงเทพมหานคร
# 4                            กลาง  เขต 13 กรุงเทพมหานคร
# ...                           ...                   ...
# 2696640                      กลาง       เขต 3 นครสวรรค์
# 2701230                      กลาง         เขต 4 สระบุรี
# 2701231                      กลาง         เขต 4 สระบุรี
# 2717714                  ตะวันออก           เขต 6 ระยอง
# 2730091                       ใต้   เขต 11 สุราษฎร์ธานี
#
#          ผลลัพธ์ปี 2562 (จังหวัด)  จำนวนครั้งปี 2562 (จังหวัด)  \
# 0                           41.49                          640
# 1                           41.49                          640
# 2                           41.49                          640
# 3                           41.49                          640
# 4                           41.49                          640
# ...                           ...                          ...
# 2696640                     58.23                           54
# 2701230                     57.41                           45
# 2701231                     57.41                           45
# 2717714                     48.65                           22
# 2730091                     63.64                           15
#
#          ผลลัพธ์ปี 2563 (จังหวัด)  จำนวนครั้งปี 2563 (จังหวัด)
# 0                           41.02                          648
# 1                           41.02                          648
# 2                           41.02                          648
# 3                           41.02                          648
# 4                           41.02                          648
# ...                           ...                          ...
# 2696640                     61.76                           58
# 2701230                     53.85                           38
# 2701231                     53.85                           38
# 2717714                     69.57                           20
# 2730091                     60.00                           19
#
# [5149 rows x 16 columns]

# %%
finish.isnull().any()
# Out:
# No.                            False
# announce_date                  False
# sex                            False
# age                            False
# Unit                           False
# province_of_onset              False
# risk                           False
# 6 ภูมิภาค (ภูมิศาสตร์)         False
# 4 ภูมิภาค (การเมือง)           False
# 6 ภูมิภาค (อุตุนิยมวิทยา)      False
# 5 ภูมิภาค (การท่องเที่ยว)      False
# county_of_local                False
# ผลลัพธ์ปี 2562 (จังหวัด)       False
# จำนวนครั้งปี 2562 (จังหวัด)    False
# ผลลัพธ์ปี 2563 (จังหวัด)       False
# จำนวนครั้งปี 2563 (จังหวัด)    False
# dtype: bool

# %%
finish.to_csv('finish', encoding = 'utf-8')
